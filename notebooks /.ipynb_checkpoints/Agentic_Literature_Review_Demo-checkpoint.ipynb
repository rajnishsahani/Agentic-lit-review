# %% [markdown]
# # Agentic Literature Review & Learning Path Recommender
#
# **CIS 600 — Applied Agentic AI Systems | Spring 2026**
#
# **Team Members:** Rajnish Sahani, Deven Wagh, Hangye Li, Yonghao Li
#
# **Instructor:** Professor Kumarawadu
#
# ---
#
# This notebook demonstrates our multi-agent system that takes a research topic as input and produces:
# - A curated set of relevant papers (from arXiv + Semantic Scholar)
# - Relevance-scored screening
# - Thematic synthesis across papers
# - Research gap identification
# - A **recommended reading order** — so a beginner knows exactly which paper to start with
#
# The actual system lives in `.py` files (agents/, controller/, tools/, etc.). This notebook imports and runs that code, then visualizes the results.

# %% [markdown]
# ## 1. Setup

# %%
import os
import sys
sys.path.insert(0, '..')

import time
import json
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())

# make sure the key is actually there
assert os.getenv("GROQ_API_KEY") is not None, "GROQ_API_KEY not found in .env"
print("API key loaded successfully")
# Out:
# API key loaded successfully

# %% [markdown]
# ## 2. Project Structure
#
# Each agent is its own file. The orchestrator wires them together using LangGraph.
#
# ```
# Agentic-lit-review/
# ├── agents/
# │   ├── search_agent.py        # generates queries, hits arXiv + Semantic Scholar
# │   ├── screening_agent.py     # scores relevance 0-1, filters out irrelevant papers
# │   ├── synthesis_agent.py     # summarizes papers, identifies themes
# │   └── planning_agent.py      # gaps, research plan, reading order
# ├── controller/
# │   └── orchestrator.py        # LangGraph StateGraph connects everything
# ├── tools/
# │   ├── arxiv_tool.py          # arXiv API wrapper
# │   └── semantic_scholar.py    # Semantic Scholar API wrapper
# ├── state/
# │   └── shared_state.py        # TypedDict state schema
# ├── evaluation/
# │   └── metrics.py             # eval metrics + baseline comparison
# ├── main.py                    # CLI entry point
# └── .env                       # API keys (not committed)
# ```

# %% [markdown]
# ## 3. State Schema
#
# The shared state flows through every agent. Each agent reads what it needs and writes its outputs back.

# %%
from state.shared_state import AgentState, Paper

import inspect
print("--- Paper ---")
print(inspect.getsource(Paper))
print("--- AgentState ---")
print(inspect.getsource(AgentState))
# Out:
# --- Paper ---
# class Paper(TypedDict):
#     title: str
#     authors: List[str]
#     abstract: str
#     year: int
#     url: str
#     relevance_score: Optional[float]
#     summary: Optional[str]
#     themes: Optional[List[str]]
#
# --- AgentState ---
# class AgentState(TypedDict):
#     # Input
#     research_topic: str
#
#     # Search Agent outputs
#     search_queries: List[str]
#     raw_papers: List[Paper]
#
#     # Screening Agent outputs
#     screened_papers: List[Paper]
#
#     # Synthesis Agent outputs
#     summaries: List[str]
#     themes: List[str]
#
#     # Planning Agent outputs
#     research_gaps: List[str]
#     research_plan: str
#     reading_order: List[dict]
#
#     # Controller
#     iteration: int
#     max_iterations: int
#     status: str
#     messages: List[str]

# %% [markdown]
# ## 4. Agent Orchestration (LangGraph)
#
# The orchestrator builds a StateGraph with 5 nodes. There's a conditional edge after screening — if we didn't find enough papers, it loops back to search. That's what makes this agentic rather than a static pipeline.

# %%
from controller.orchestrator import build_graph
import inspect

print(inspect.getsource(build_graph))
# Out:
# def build_graph():
#     """Build and return the LangGraph workflow."""
#     workflow = StateGraph(AgentState)
#
#     # Add nodes
#     workflow.add_node("search", search_agent)
#     workflow.add_node("delay_1", delay_node)
#     workflow.add_node("screen", screening_agent)
#     workflow.add_node("increment", increment_iteration)
#     workflow.add_node("delay_2", delay_node)
#     workflow.add_node("synthesize", synthesis_agent)
#     workflow.add_node("delay_3", delay_node)
#     workflow.add_node("plan", planning_agent)
#
#     # Set entry point
#     workflow.set_entry_point("search")
#
#     # Add edges with delays between agents
#     workflow.add_edge("search", "delay_1")
#     workflow.add_edge("delay_1", "screen")
#     workflow.add_edge("screen", "increment")
#
#     # Conditional edge: loop back or continue
#     workflow.add_conditional_edges(
#         "increment",
#         should_continue,
#         {
#             "search_again": "search",
#             "end": "delay_2"
#         }
#     )
#
#     workflow.add_edge("delay_2", "synthesize")
#     workflow.add_edge("synthesize", "delay_3")
#     workflow.add_edge("delay_3", "plan")
#     workflow.add_edge("plan", END)
#
#     return workflow.compile()

# %% [markdown]
# ### Graph Flow
#
# ```
#                     ┌──────────────────────────────────────┐
#                     │                                      │
#                     ▼                                      │
#     [Search Agent] ──→ [Screening Agent] ──→ [Increment]  │
#                                                  │        │
#                                         ┌────────┴────────┘
#                                         │  (< 3 papers? loop back)
#                                         │
#                                         ▼
#                                   [Synthesis Agent] ──→ [Planning Agent] ──→ END
# ```
#
# The LLM is initialized **inside** each agent function, not at module level. This means swapping providers is a one-line change per file. We started with Gemini, hit quota limits, switched to Groq in 5 minutes.

# %% [markdown]
# ## 5. Running the Full Pipeline

# %%
from controller.orchestrator import run_literature_review

topic = "symbol grounding"

print(f"Running literature review for: {topic}")
print("This takes about a minute (rate limit delays between agents)...\n")

start_time = time.time()
result = run_literature_review(topic, max_iterations=2)
elapsed = time.time() - start_time

print(f"\nDone in {elapsed:.1f}s")
# Out:
# Running literature review for: zero-shot learning
# This takes about a minute (rate limit delays between agents)...
#
#
# [Search Agent] Searching for: zero-shot learning
# [Search Agent] Generated queries: ['zero-shot learning AND deep learning', 'few-shot learning OR meta-learning AND transfer learning', 'zero-shot classification OR image recognition AND semantic embedding']
# [Semantic Scholar] Request failed: 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=zero-shot+learning+AND+deep+learning&limit=5&fields=title%2Cauthors%2Cabstract%2Cyear%2CexternalIds%2CopenAccessPdf
# [Semantic Scholar] Request failed: 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=few-shot+learning+OR+meta-learning+AND+transfer+learning&limit=5&fields=title%2Cauthors%2Cabstract%2Cyear%2CexternalIds%2CopenAccessPdf
# [Semantic Scholar] Request failed: 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=zero-shot+classification+OR+image+recognition+AND+semantic+embedding&limit=5&fields=title%2Cauthors%2Cabstract%2Cyear%2CexternalIds%2CopenAccessPdf
# [Search Agent] Found 15 unique papers (arXiv + Semantic Scholar)
# [Orchestrator] Waiting 10s for rate limit...
#
# [Screening Agent] Screening 15 papers...
# [Screening Agent] 7 papers passed screening
# [Orchestrator] Waiting 10s for rate limit...
#
# [Synthesis Agent] Synthesizing 7 papers...
# [Synthesis Agent] Identified themes: ['Zero-Shot Learning and Few-Shot Classification', 'Meta-Learning and Transfer Learning', 'Probabilistic Inference and Uncertainty Modeling']
# [Orchestrator] Waiting 10s for rate limit...
#
# [Planning Agent] Generating research plan and reading order...
# [Planning Agent] Research plan generated
# [Planning Agent] Reading order: 7 papers sequenced
#
# Done in 48.6s

# %% [markdown]
# ## 6. Results
#
# ### 6.1 Papers Retrieved & Screened

# %%
print(f"Topic: {result['research_topic']}")
print(f"Search queries generated: {len(result['search_queries'])}")
print(f"Total papers found: {len(result['raw_papers'])}")
print(f"Papers after screening: {len(result['screened_papers'])}")
print(f"Rejection rate: {(len(result['raw_papers']) - len(result['screened_papers'])) / len(result['raw_papers']):.0%}")

print("\n--- Top 5 Papers by Relevance ---")
for i, p in enumerate(result['screened_papers'][:5], 1):
    print(f"\n{i}. {p['title']} ({p.get('year', '?')})")
    print(f"   Relevance: {p.get('relevance_score', 0):.2f}")
    print(f"   Summary: {p.get('summary', 'N/A')[:150]}...")
# Out:
# Topic: zero-shot learning
# Search queries generated: 3
# Total papers found: 15
# Papers after screening: 7
# Rejection rate: 53%
#
# --- Top 5 Papers by Relevance ---
#
# 1. Generalized Continual Zero-Shot Learning (2020)
#    Relevance: 1.00
#    Summary: This paper discusses the concept of generalized continual zero-shot learning, which aims to classify unseen classes by transferring knowledge from see...
#
# 2. Zero-Shot Recognition using Dual Visual-Semantic Mapping Paths (2017)
#    Relevance: 1.00
#    Summary: This paper proposes a dual visual-semantic mapping approach for zero-shot recognition, which learns a shared mapping between the image feature space a...
#
# 3. Fine-Grained Object Recognition and Zero-Shot Learning in Remote Sensing Imagery (2017)
#    Relevance: 0.90
#    Summary: This paper explores the application of fine-grained object recognition and zero-shot learning in remote sensing imagery, where traditional fully super...
#
# 4. Regression Networks for Meta-Learning Few-Shot Classification (2019)
#    Relevance: 0.80
#    Summary: This paper introduces regression networks for meta-learning few-shot classification, which aims to generalize to new classes not seen in the training ...
#
# 5. Few-shot Learning with Meta Metric Learners (2019)
#    Relevance: 0.70
#    Summary: This paper discusses few-shot learning with meta metric learners, which aims to learn classifiers for new classes with only a few training examples pe...

# %% [markdown]
# ### 6.2 Themes Identified

# %%
print("Themes found across all screened papers:\n")
for i, theme in enumerate(result['themes'], 1):
    print(f"  {i}. {theme}")
# Out:
# Themes found across all screened papers:
#
#   1. Zero-Shot Learning and Few-Shot Classification
#   2. Meta-Learning and Transfer Learning
#   3. Probabilistic Inference and Uncertainty Modeling

# %% [markdown]
# ### 6.3 Research Gaps

# %%
print("Identified gaps in the literature:\n")
for i, gap in enumerate(result['research_gaps'], 1):
    print(f"  {i}. {gap}")
# Out:
# Identified gaps in the literature:
#
#   1. Investigating the role of uncertainty modeling in zero-shot learning
#   2. Developing more efficient meta-learning algorithms for few-shot classification
#   3. Exploring the application of zero-shot learning in multimodal and multilingual settings

# %% [markdown]
# ### 6.4 Research Plan

# %%
print(result['research_plan'])
# Out:
# The proposed research plan aims to address the gaps in zero-shot learning by investigating the role of uncertainty modeling, developing more efficient meta-learning algorithms, and exploring the application of zero-shot learning in multimodal and multilingual settings. The research questions are:
# 1. How can uncertainty modeling be effectively incorporated into zero-shot learning frameworks to improve their robustness and accuracy?
# 2. What are the key factors that influence the performance of meta-learning algorithms in few-shot classification, and how can they be optimized?
# 3. Can zero-shot learning be successfully applied to multimodal and multilingual settings, and what are the challenges and opportunities in these areas?
#
# The methodology will involve a combination of theoretical analysis, experimental evaluation, and case studies. Theoretical analysis will be used to investigate the role of uncertainty modeling in zero-shot learning and to develop new meta-learning algorithms. Experimental evaluation will be used to compare the performance of different zero-shot learning approaches and to test the effectiveness of the proposed algorithms. Case studies will be used to explore the application of zero-shot learning in multimodal and multilingual settings.
#
# The evaluation strategy will involve a combination of quantitative and qualitative metrics. Quantitative metrics will include accuracy, precision, recall, and F1-score, while qualitative metrics will include robustness, interpretability, and scalability. The evaluation will be performed on a range of benchmark datasets, including image and text classification datasets.

# %% [markdown]
# ### 6.5 Recommended Reading Order (Learning Path)
#
# This is the main feature — not just finding papers but telling you **which order to read them in**. The LLM considers concept dependencies: surveys first, foundational work next, then specialized extensions.

# %%
reading_order = result.get('reading_order', [])

if reading_order:
    print(f"Recommended reading sequence ({len(reading_order)} papers):\n")
    for entry in reading_order:
        pos = entry.get('position', '?')
        title = entry.get('title', 'Unknown')
        reason = entry.get('reason', '')
        print(f"  [{pos}] {title}")
        print(f"      -> {reason}")
        print()
else:
    print("No reading order generated")
# Out:
# Recommended reading sequence (7 papers):
#
#   [1] Zero-Shot Recognition using Dual Visual-Semantic Mapping Paths
#       -> This paper provides a foundational introduction to zero-shot learning and proposes a dual visual-semantic mapping approach for zero-shot recognition, which is a key concept in the field.
#
#   [2] Generalized Continual Zero-Shot Learning
#       -> This paper discusses the concept of generalized continual zero-shot learning and proposes a new framework to address the challenges of existing zero-shot learning approaches, providing a good overview of the current state of the field.
#
#   [3] Regression Networks for Meta-Learning Few-Shot Classification
#       -> This paper introduces regression networks for meta-learning few-shot classification, which is a key technique in zero-shot learning, and provides a good introduction to the concept of meta-learning.
#
#   [4] Meta-Learning Probabilistic Inference For Prediction
#       -> This paper introduces a new framework for meta-learning probabilistic inference for prediction, which is relevant to the topic of uncertainty modeling in zero-shot learning.
#
#   [5] Alpha MAML: Adaptive Model-Agnostic Meta-Learning
#       -> This paper proposes an adaptive model-agnostic meta-learning technique that trains a model on multiple learning tasks to prime it for few-shot learning of new tasks, which is a key concept in meta-learning.
#
#   [6] Few-shot Learning with Meta Metric Learners
#       -> This paper discusses few-shot learning with meta metric learners, which is a relevant topic in zero-shot learning, and provides a good introduction to the concept of metric learning.
#
#   [7] Fine-Grained Object Recognition and Zero-Shot Learning in Remote Sensing Imagery
#       -> This paper explores the application of fine-grained object recognition and zero-shot learning in remote sensing imagery, which is a specific application area of zero-shot learning, and can be read last to provide a concrete example of the concepts learned from the previous papers.

# %% [markdown]
# ## 7. Visualizations

# %% [markdown]
# ### 7.1 Relevance Score Distribution

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

scores = [p.get('relevance_score', 0) for p in result['screened_papers']]
titles = [p['title'][:40] + '...' if len(p['title']) > 40 else p['title'] 
          for p in result['screened_papers']]

fig, ax = plt.subplots(figsize=(10, 6))
colors = ['#2ecc71' if s >= 0.8 else '#f39c12' for s in scores]
ax.barh(range(len(scores)), scores, color=colors)
ax.set_yticks(range(len(titles)))
ax.set_yticklabels(titles, fontsize=8)
ax.set_xlabel('Relevance Score')
ax.set_title('Paper Relevance Scores (after screening)')
ax.set_xlim(0, 1.1)
ax.invert_yaxis()

for i, s in enumerate(scores):
    ax.text(s + 0.02, i, f'{s:.2f}', va='center', fontsize=8)

plt.tight_layout()
plt.savefig('relevance_scores.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 7.2 Source Diversity

# %%
papers = result['raw_papers']
arxiv_count = sum(1 for p in papers if 'arxiv' in p.get('url', '').lower())
ss_count = len(papers) - arxiv_count

fig, ax = plt.subplots(figsize=(6, 4))
ax.bar(['arXiv', 'Semantic Scholar'], [arxiv_count, ss_count], color=['#3498db', '#e74c3c'])
ax.set_ylabel('Number of Papers')
ax.set_title('Papers by Source')

for i, v in enumerate([arxiv_count, ss_count]):
    ax.text(i, v + 0.3, str(v), ha='center', fontweight='bold')

plt.tight_layout()
plt.savefig('source_diversity.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"arXiv: {arxiv_count}, Semantic Scholar: {ss_count}")
# Out:
# arXiv: 15, Semantic Scholar: 0

# %% [markdown]
# ### 7.3 Reading Order Visualization

# %%
reading_order = result.get('reading_order', [])

if reading_order:
    fig, ax = plt.subplots(figsize=(12, 6))
    
    positions = [entry.get('position', i+1) for i, entry in enumerate(reading_order)]
    short_titles = [entry.get('title', '')[:45] + '...' if len(entry.get('title', '')) > 45 
                    else entry.get('title', '') for entry in reading_order]
    
    colors = plt.cm.viridis([i / len(reading_order) for i in range(len(reading_order))])
    
    ax.barh(range(len(positions)), positions, color=colors)
    ax.set_yticks(range(len(short_titles)))
    ax.set_yticklabels(short_titles, fontsize=7)
    ax.set_xlabel('Reading Position')
    ax.set_title('Recommended Reading Order (1 = read first)')
    ax.invert_yaxis()
    
    plt.tight_layout()
    plt.savefig('reading_order.png', dpi=150, bbox_inches='tight')
    plt.show()

# %% [markdown]
# ### 7.4 Papers by Publication Year

# %%
years = [p.get('year', 0) for p in result['screened_papers'] if p.get('year')]
year_counts = {}
for y in years:
    year_counts[y] = year_counts.get(y, 0) + 1

sorted_years = sorted(year_counts.keys())
counts = [year_counts[y] for y in sorted_years]

fig, ax = plt.subplots(figsize=(8, 4))
ax.bar([str(y) for y in sorted_years], counts, color='#9b59b6')
ax.set_xlabel('Year')
ax.set_ylabel('Number of Papers')
ax.set_title('Screened Papers by Publication Year')

for i, v in enumerate(counts):
    ax.text(i, v + 0.1, str(v), ha='center', fontweight='bold')

plt.tight_layout()
plt.savefig('papers_by_year.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8. Evaluation
#
# Full evaluation suite: tool metrics, planning metrics, retrieval quality, efficiency, and baseline comparison. The baseline is a plain arXiv keyword search with no LLM involvement — this is what a student would get by just searching arXiv manually.

# %%
from evaluation.metrics import evaluate_run

eval_results = evaluate_run(result, elapsed, topic)
# Out:
# ============================================================
# EVALUATION RESULTS
# ============================================================
#
# --- TOOL METRICS ---
#   Tool Selection Accuracy: 0.67
#   Tool Execution Success:  1.00 (4/4)
#     search: PASS (arXiv + Semantic Scholar retrieval)
#     screening: PASS (LLM relevance scoring)
#     synthesis: PASS (LLM summarization + theme extraction)
#     planning: PASS (LLM gap analysis + plan generation)
#
# --- PLANNING METRICS ---
#   Step Success Rate:    1.00 (7/7)
#     Query Generation: PASS
#     Paper Retrieval: PASS
#     Relevance Screening: PASS
#     Summarization: PASS
#     Theme Identification: PASS
#     Gap Analysis: PASS
#     Research Plan: PASS
#   Task Completion Rate: 1.00 (4/4)
#
# --- RETRIEVAL & SCREENING METRICS ---
#   Screening Precision:  1.00
#   Coverage: 7/15 papers retained (0.47)
#   Source Diversity:     arXiv=15, Semantic Scholar=0 (score: 0.0)
#   Relevance Scores:    mean=0.786, min=0.5, max=1.0
#
# --- EFFICIENCY METRICS ---
#   Execution Time:      48.56s
#   LLM API Calls:    ~4
#   Iterations Used:     1
#   Time Per Paper:      3.24s
#
# --- BASELINE COMPARISON (Agentic vs Non-Agentic) ---
#   Total Papers Retrieved:
#     Agentic:  15
#     Baseline: 10
#     → More
#   Relevant Papers (Screened):
#     Agentic:  7
#     Baseline: 10 (unfiltered)
#     → Quality filtered
#   Search Sources:
#     Agentic:  arXiv + Semantic Scholar
#     Baseline: arXiv only
#     → Multi-source
#   Query Strategy:
#     Agentic:  3 LLM-generated queries
#     Baseline: 1 keyword query
#     → Diverse coverage
#   Paper Summaries:
#     Agentic:  7 generated
#     Baseline: None
#     → Automated synthesis
#   Theme Identification:
#     Agentic:  3 themes
#     Baseline: None
#     → Cross-paper analysis
#   Research Gaps:
#     Agentic:  3 identified
#     Baseline: None
#     → Gap analysis
#   Research Plan:
#     Agentic:  Generated
#     Baseline: None
#     → Structured planning
#   Execution Time:
#     Agentic:  48.6s
#     Baseline: 0.2s
#     → Slower but comprehensive
#   LLM API Calls:
#     Agentic:  ~4 (batched)
#     Baseline: 0
#     → Intelligence cost
#
# ============================================================

# %% [markdown]
# ### 8.1 Agentic vs Baseline Comparison

# %%
categories = ['Papers Found', 'Sources Used', 'LLM Queries', 'Summaries', 'Themes', 'Gaps Found']
agentic_vals = [
    len(result['raw_papers']), 2, len(result['search_queries']),
    len(result['summaries']), len(result['themes']), len(result['research_gaps'])
]
baseline_vals = [10, 1, 1, 0, 0, 0]

x = range(len(categories))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 5))
bars1 = ax.bar([i - width/2 for i in x], agentic_vals, width, label='Agentic System', color='#2ecc71')
bars2 = ax.bar([i + width/2 for i in x], baseline_vals, width, label='Baseline (keyword search)', color='#e74c3c')

ax.set_ylabel('Count')
ax.set_title('Agentic System vs Non-Agentic Baseline')
ax.set_xticks(x)
ax.set_xticklabels(categories, rotation=15)
ax.legend()

for bar in bars1:
    ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.3,
            str(int(bar.get_height())), ha='center', fontsize=9)
for bar in bars2:
    ax.text(bar.get_x() + bar.get_width()/2., bar.get_height() + 0.3,
            str(int(bar.get_height())), ha='center', fontsize=9)

plt.tight_layout()
plt.savefig('agentic_vs_baseline.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 9. Second Run — Different Topic
#
# Running with a different topic to show the system generalizes.

# %%
topic2 = "reinforcement learning from human feedback"

print(f"Running literature review for: {topic2}\n")

start2 = time.time()
result2 = run_literature_review(topic2, max_iterations=2)
elapsed2 = time.time() - start2

print(f"\nDone in {elapsed2:.1f}s")
print(f"Papers found: {len(result2['raw_papers'])}")
print(f"After screening: {len(result2['screened_papers'])}")
print(f"Themes: {result2['themes']}")
print(f"Gaps: {len(result2['research_gaps'])}")
print(f"Reading order: {len(result2.get('reading_order', []))} papers sequenced")
# Out:
# Running literature review for: reinforcement learning from human feedback
#
#
# [Search Agent] Searching for: reinforcement learning from human feedback
# [Search Agent] Generated queries: ['reinforcement learning from human feedback', 'deep reinforcement learning with human preferences', 'inverse reinforcement learning from human demonstrations']
# [Semantic Scholar] Found 5 papers for: reinforcement learning from human feedback
# [Semantic Scholar] Request failed: 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=deep+reinforcement+learning+with+human+preferences&limit=5&fields=title%2Cauthors%2Cabstract%2Cyear%2CexternalIds%2CopenAccessPdf
# [Semantic Scholar] Request failed: 429 Client Error:  for url: https://api.semanticscholar.org/graph/v1/paper/search?query=inverse+reinforcement+learning+from+human+demonstrations&limit=5&fields=title%2Cauthors%2Cabstract%2Cyear%2CexternalIds%2CopenAccessPdf
# [Search Agent] Found 18 unique papers (arXiv + Semantic Scholar)
# [Orchestrator] Waiting 10s for rate limit...
#
# [Screening Agent] Screening 18 papers...
# [Screening Agent] 11 papers passed screening
# [Orchestrator] Waiting 10s for rate limit...
#
# [Synthesis Agent] Synthesizing 11 papers...
# [Synthesis Agent] Identified themes: ['Reinforcement Learning from Human Feedback', 'Safety and Reliability in AI Systems', 'Human-Centered AI Development', 'Pluralism and Diversity in AI', 'Scalability and Efficiency in RLHF']
# [Orchestrator] Waiting 10s for rate limit...
#
# [Planning Agent] Generating research plan and reading order...
# [Planning Agent] Research plan generated
# [Planning Agent] Reading order: 11 papers sequenced
#
# Done in 50.4s
# Papers found: 18
# After screening: 11
# Themes: ['Reinforcement Learning from Human Feedback', 'Safety and Reliability in AI Systems', 'Human-Centered AI Development', 'Pluralism and Diversity in AI', 'Scalability and Efficiency in RLHF']
# Gaps: 3
# Reading order: 11 papers sequenced

# %%
# reading order for the second topic
reading_order2 = result2.get('reading_order', [])

if reading_order2:
    print(f"Reading path for '{topic2}':\n")
    for entry in reading_order2:
        pos = entry.get('position', '?')
        title = entry.get('title', 'Unknown')
        reason = entry.get('reason', '')
        print(f"  [{pos}] {title}")
        print(f"      -> {reason}")
        print()
# Out:
# Reading path for 'reinforcement learning from human feedback':
#
#   [1] Reinforcement Learning from Human Feedback
#       -> This book provides a gentle introduction to reinforcement learning from human feedback, covering its core methods and origins, making it a foundational paper to start with
#
#   [2] Open Problems and Fundamental Limitations of Reinforcement Learning from Human Feedback
#       -> This paper surveys open problems and fundamental limitations of reinforcement learning from human feedback, providing a foundation for understanding the challenges and gaps in the field
#
#   [3] Humans are not Boltzmann Distributions: Challenges and Opportunities for Modelling Human Feedback and Interaction in Reinforcement Learning
#       -> This paper challenges common assumptions in reinforcement learning and proposes more realistic models of human feedback, highlighting the need for more sophisticated approaches to learning from human interaction
#
#   [4] Safe RLHF: Safe Reinforcement Learning from Human Feedback
#       -> This paper proposes a novel algorithm for safe reinforcement learning from human feedback, addressing the challenge of balancing performance and safety in AI systems
#
#   [5] RLHF-Blender: A Configurable Interactive Interface for Learning from Diverse Human Feedback
#       -> This paper introduces a configurable interactive interface for learning from diverse human feedback, which has the potential to improve the effectiveness of reinforcement learning from human feedback
#
#   [6] Reinforcement Learning from Human Feedback: Whose Culture, Whose Values, Whose Perspectives?
#       -> This paper argues for the importance of pluralism in reinforcement learning from human feedback, highlighting the need for diverse perspectives and values in the development of large language models
#
#   [7] Training a Helpful and Harmless Assistant with Reinforcement Learning from Human Feedback
#       -> This paper applies preference modeling and reinforcement learning from human feedback to fine-tune language models, resulting in helpful and harmless assistants
#
#   [8] RLAIF vs. RLHF: Scaling Reinforcement Learning from Human Feedback with AI Feedback
#       -> This paper compares reinforcement learning from human feedback with reinforcement learning from AI feedback, evaluating their effectiveness in scaling RLHF
#
#   [9] Directed Policy Gradient for Safe Reinforcement Learning with Human Advice
#       -> This paper introduces a directed policy gradient approach for safe reinforcement learning with human advice, aiming to improve the safety and effectiveness of RL agents
#
#   [10] Mixing Human Demonstrations with Self-Exploration in Experience Replay for Deep Reinforcement Learning
#       -> This paper investigates the effect of mixing human demonstrations with self-exploration in experience replay for deep reinforcement learning, providing insights into the benefits and limitations of this approach
#
#   [11] Exploring Hierarchy-Aware Inverse Reinforcement Learning
#       -> This paper introduces a new generative model for human planning under the Bayesian Inverse Reinforcement Learning framework, taking into account hierarchical strategies, and can be read last as it is a more specialized topic

# %%
eval_results2 = evaluate_run(result2, elapsed2, topic2)
# Out:
# ============================================================
# EVALUATION RESULTS
# ============================================================
#
# --- TOOL METRICS ---
#   Tool Selection Accuracy: 1.00
#   Tool Execution Success:  1.00 (4/4)
#     search: PASS (arXiv + Semantic Scholar retrieval)
#     screening: PASS (LLM relevance scoring)
#     synthesis: PASS (LLM summarization + theme extraction)
#     planning: PASS (LLM gap analysis + plan generation)
#
# --- PLANNING METRICS ---
#   Step Success Rate:    1.00 (7/7)
#     Query Generation: PASS
#     Paper Retrieval: PASS
#     Relevance Screening: PASS
#     Summarization: PASS
#     Theme Identification: PASS
#     Gap Analysis: PASS
#     Research Plan: PASS
#   Task Completion Rate: 1.00 (4/4)
#
# --- RETRIEVAL & SCREENING METRICS ---
#   Screening Precision:  1.00
#   Coverage: 11/18 papers retained (0.61)
#   Source Diversity:     arXiv=16, Semantic Scholar=2 (score: 0.125)
#   Relevance Scores:    mean=0.745, min=0.5, max=0.9
#
# --- EFFICIENCY METRICS ---
#   Execution Time:      50.38s
#   LLM API Calls:    ~4
#   Iterations Used:     1
#   Time Per Paper:      2.8s
#
# --- BASELINE COMPARISON (Agentic vs Non-Agentic) ---
#   Total Papers Retrieved:
#     Agentic:  18
#     Baseline: 10
#     → More
#   Relevant Papers (Screened):
#     Agentic:  11
#     Baseline: 10 (unfiltered)
#     → Quality filtered
#   Search Sources:
#     Agentic:  arXiv + Semantic Scholar
#     Baseline: arXiv only
#     → Multi-source
#   Query Strategy:
#     Agentic:  3 LLM-generated queries
#     Baseline: 1 keyword query
#     → Diverse coverage
#   Paper Summaries:
#     Agentic:  11 generated
#     Baseline: None
#     → Automated synthesis
#   Theme Identification:
#     Agentic:  5 themes
#     Baseline: None
#     → Cross-paper analysis
#   Research Gaps:
#     Agentic:  3 identified
#     Baseline: None
#     → Gap analysis
#   Research Plan:
#     Agentic:  Generated
#     Baseline: None
#     → Structured planning
#   Execution Time:
#     Agentic:  50.4s
#     Baseline: 0.26s
#     → Slower but comprehensive
#   LLM API Calls:
#     Agentic:  ~4 (batched)
#     Baseline: 0
#     → Intelligence cost
#
# ============================================================

# %% [markdown]
# ## 10. Technology Stack
#
# | Component | Technology | Why |
# |-----------|-----------|-----|
# | Agent Orchestration | LangGraph | Stateful cyclic graphs, conditional edges for adaptive behavior |
# | LLM | Groq (Llama 3.3 70B) | Free tier, generous limits, fast inference |
# | Paper Retrieval | arXiv API + Semantic Scholar API | Two sources for better coverage |
# | Framework | LangChain v0.3+ | Prompt templates, chain composition |
# | State Management | Python TypedDict | Type-safe, works natively with LangGraph |
# | Environment | Python 3.11, virtualenv | Standard setup |
#
# We started with Google Gemini but ran into daily quota exhaustion during testing. The architecture is provider-agnostic — the LLM is initialized inside each agent function, so switching to Groq took about 5 minutes.

# %% [markdown]
# ## 11. Summary
#
# The system works end-to-end: given a research topic, it searches for papers across multiple sources, screens them for relevance, synthesizes themes, identifies gaps, and produces a **recommended reading order** for someone new to the topic.
#
# **What makes it agentic:**
# - LLM-driven query generation (not hardcoded keywords)
# - Adaptive feedback loop — re-searches if not enough relevant papers
# - LLM-based screening with numeric relevance scoring
# - Cross-paper synthesis (themes emerge from the collection, not individual papers)
# - Reading order reasoning based on concept dependencies
#
# **Limitations:**
# - Semantic Scholar has aggressive rate limits (429s are common)
# - Reading order relies on LLM judgment, no citation graph analysis yet
# - Relevance scores are LLM-generated, not validated against human judgments
#
# **Possible extensions:**
# - Citation graph analysis for more robust reading order
# - PDF download + full-text analysis instead of abstract-only
# - Interactive UI (Streamlit/Gradio) for non-technical users
